# %% [markdown]
# # Week 3 Exercises Notebook
#
# Use this notebook to work through the Week 3 exercises.
#
# Topics:
# - divisibility
# - factors
# - gcd and lcm
# - prime numbers
# - algebra

# %%
# Start your Week 3 exercise code here
