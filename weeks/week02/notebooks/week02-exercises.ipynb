# %% [markdown]
# # Week 2 Exercises Notebook
#
# Use this notebook to work through the Week 2 exercises.
#
# Topics:
# - problem solving
# - coordinates
# - tables of values
# - patterns
# - helper functions
# - plotting

# %%
# Start your Week 2 exercise code here
