# %% [markdown]
# # Week 1 Exercises Notebook
#
# Use this notebook to work through the Week 1 exercises.
#
# Topics:
# - arithmetic
# - variables
# - conditionals
# - loops
# - lists
# - functions

# %%
# Start your Week 1 exercise code here
